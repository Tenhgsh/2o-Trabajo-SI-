# %% [markdown]
# # Sistemas Inteligentes

# %%
# !pip install swig
# !pip install gymnasium[classic-control]
# Out:
# Collecting swig
#   Downloading swig-4.4.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Downloading swig-4.4.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 19.6 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.4.1
# Requirement already satisfied: gymnasium[classic-control] in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[classic-control]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[classic-control]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[classic-control]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[classic-control]) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from gymnasium[classic-control]) (2.6.1)

# %%
import math
import random
from collections import deque
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import gymnasium as gym
import imageio
from google.colab import files

# %%
class QNetwork(nn.Module):
    def __init__(self, state_size, action_size):
        super().__init__()
        self.fc1 = nn.Linear(state_size, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, action_size)

    def forward(self, x):
        # Utiliza relu como función de activación
        # fc1 - relu - fc2 - relu - fc3
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc3(x)

# %%
class ReplayBuffer:
    def __init__(self, capacity):
        self.memory = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        # Define la tupla de experiencia
        experience_tuple = (state, action, reward, next_state, done)
        # Añade la tupla de experiencia a la memoria
        self.memory.append(experience_tuple)

    def __len__(self):
        return len(self.memory)

    def sample(self, batch_size):
        # Toma una muestra aleatoria de la memoria de tamaño batch_size
        batch = random.sample(self.memory, batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        states_tensor = torch.tensor(np.array(states), dtype=torch.float32)
        next_states_tensor = torch.tensor(np.array(next_states), dtype=torch.float32)
        rewards_tensor = torch.tensor(rewards, dtype=torch.float32)
        dones_tensor = torch.tensor(dones, dtype=torch.float32)
        actions_tensor = torch.tensor(actions, dtype=torch.long).unsqueeze(1)

        return states_tensor, actions_tensor, rewards_tensor, next_states_tensor, dones_tensor

# %%
def select_action(q_values, epsilon):
    if np.random.rand() < epsilon:
        # Escoge la acción aleatoria
        return random.choice(range(len(q_values)))
    else:
        # Escoge la acción greedy
        return torch.argmax(q_values).item()


def epsilon_decay_by_step(step, start, end, decay):
    return end + (start - end) * math.exp(-step / decay)

# %%
def update_target_network(target_network, online_network, tau):
    target_net_state_dict = target_network.state_dict()
    online_net_state_dict = online_network.state_dict()

    for key in online_net_state_dict:
        target_net_state_dict[key] = (
            online_net_state_dict[key] * tau +
            target_net_state_dict[key] * (1 - tau))

    target_network.load_state_dict(target_net_state_dict)

# %%
env = gym.make("CartPole-v1")
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

online_network = QNetwork(state_size, action_size)
target_network = QNetwork(state_size, action_size)
target_network.load_state_dict(online_network.state_dict())

optimizer = optim.Adam(online_network.parameters(), lr=1e-4)
loss_fn = nn.MSELoss()

buffer_size = 100_000
replay_buffer = ReplayBuffer(capacity=buffer_size)

# %%
batch_size = 64
gamma = 0.99
tau = 0.5
num_training_episodes = 1000
max_steps_per_episode = 1000
learning_starts = 1000
target_update_interval = 100

# %%
total_steps = 0
for episode in range(num_training_episodes):
    # Reset
    state, _ = env.reset()
    episode_reward = 0.0
    done = False

    for _ in range(max_steps_per_episode):
        total_steps += 1

        # Epsilon decay
        #epsilon = epsilon_decay_by_step(total_steps, start=0.8, end=0.05, decay=100000)
        epsilon = 0.15
        with torch.no_grad():
            state_t = torch.as_tensor(state, dtype=torch.float32).unsqueeze(0)
            q_values = online_network(state_t).squeeze(0)
        # Selecciona la acción
        action = select_action(q_values, epsilon)

        # Ejecuta un paso en el entorno según la acción escogida
        next_state, reward, terminated, truncated, _ = env.step(action)
        # Actualización del indicador done
        done = terminated or truncated

        # Agrega la nueva experiencia al replay buffer
        replay_buffer.push(state, action, reward, next_state, done)

        # Asegura que se hayan ejecutado los timesteps especificados por learning_starts
        # y que el replay_buffer disponga de al menos batch_size experiencias para muestrear
        if (total_steps >= learning_starts) and (len(replay_buffer) >= batch_size):
            # Muestrea un lote de experiencias del replay_buffer de tamaño batch_size
            states, actions, rewards, next_states, dones = replay_buffer.sample(batch_size)

            # Predicción de la online network
            q_pred = online_network(states).gather(1, actions).squeeze(1)

            # Cálculo del target con la target network
            with torch.no_grad():
              next_actions = online_network(next_states).argmax(dim=1)              # [B]
              next_q = target_network(next_states).gather(1, next_actions.unsqueeze(1)).squeeze(1)  # [B]
              target = rewards + gamma * next_q * (1.0 - dones)


            # Cálculo de la pérdida MSE
            loss = loss_fn(q_pred, target)

            # Backpropagation
            optimizer.zero_grad()
            loss.backward()
            # Limita la norma de los gradientes para evitar exploding gradient y mejorar estabilidad
            nn.utils.clip_grad_norm_(online_network.parameters(), max_norm=10.0)
            optimizer.step()

            # Copia de los pesos de la online network a la target network
            # cada target_update_interval steps
            if total_steps % target_update_interval == 0:
                update_target_network(target_network, online_network, tau)

        state = next_state
        episode_reward += reward

        if done:
            break

    print(f"Episode {episode} | steps={total_steps} | ε={epsilon:.3f} | reward={episode_reward:.1f}")
# Out:
# Episode 0 | steps=8 | ε=0.150 | reward=8.0
# Episode 1 | steps=17 | ε=0.150 | reward=9.0
# Episode 2 | steps=28 | ε=0.150 | reward=11.0
# Episode 3 | steps=37 | ε=0.150 | reward=9.0
# Episode 4 | steps=48 | ε=0.150 | reward=11.0
# Episode 5 | steps=60 | ε=0.150 | reward=12.0
# Episode 6 | steps=69 | ε=0.150 | reward=9.0
# Episode 7 | steps=81 | ε=0.150 | reward=12.0
# Episode 8 | steps=92 | ε=0.150 | reward=11.0
# Episode 9 | steps=101 | ε=0.150 | reward=9.0
# Episode 10 | steps=113 | ε=0.150 | reward=12.0
# Episode 11 | steps=122 | ε=0.150 | reward=9.0
# Episode 12 | steps=130 | ε=0.150 | reward=8.0
# Episode 13 | steps=139 | ε=0.150 | reward=9.0
# Episode 14 | steps=150 | ε=0.150 | reward=11.0
# Episode 15 | steps=159 | ε=0.150 | reward=9.0
# Episode 16 | steps=169 | ε=0.150 | reward=10.0
# Episode 17 | steps=179 | ε=0.150 | reward=10.0
# Episode 18 | steps=188 | ε=0.150 | reward=9.0
# Episode 19 | steps=199 | ε=0.150 | reward=11.0
# Episode 20 | steps=209 | ε=0.150 | reward=10.0
# Episode 21 | steps=218 | ε=0.150 | reward=9.0
# Episode 22 | steps=230 | ε=0.150 | reward=12.0
# Episode 23 | steps=240 | ε=0.150 | reward=10.0
# Episode 24 | steps=249 | ε=0.150 | reward=9.0
# Episode 25 | steps=259 | ε=0.150 | reward=10.0
# Episode 26 | steps=268 | ε=0.150 | reward=9.0
# Episode 27 | steps=278 | ε=0.150 | reward=10.0
# Episode 28 | steps=288 | ε=0.150 | reward=10.0
# Episode 29 | steps=305 | ε=0.150 | reward=17.0
# Episode 30 | steps=316 | ε=0.150 | reward=11.0
# Episode 31 | steps=325 | ε=0.150 | reward=9.0
# Episode 32 | steps=336 | ε=0.150 | reward=11.0
# Episode 33 | steps=347 | ε=0.150 | reward=11.0
# Episode 34 | steps=356 | ε=0.150 | reward=9.0
# Episode 35 | steps=366 | ε=0.150 | reward=10.0
# Episode 36 | steps=378 | ε=0.150 | reward=12.0
# Episode 37 | steps=389 | ε=0.150 | reward=11.0
# Episode 38 | steps=399 | ε=0.150 | reward=10.0
# Episode 39 | steps=412 | ε=0.150 | reward=13.0
# Episode 40 | steps=423 | ε=0.150 | reward=11.0
# Episode 41 | steps=438 | ε=0.150 | reward=15.0
# Episode 42 | steps=449 | ε=0.150 | reward=11.0
# Episode 43 | steps=461 | ε=0.150 | reward=12.0
# Episode 44 | steps=470 | ε=0.150 | reward=9.0
# Episode 45 | steps=481 | ε=0.150 | reward=11.0
# Episode 46 | steps=491 | ε=0.150 | reward=10.0
# Episode 47 | steps=501 | ε=0.150 | reward=10.0
# Episode 48 | steps=511 | ε=0.150 | reward=10.0
# Episode 49 | steps=521 | ε=0.150 | reward=10.0
# Episode 50 | steps=534 | ε=0.150 | reward=13.0
# Episode 51 | steps=545 | ε=0.150 | reward=11.0
# Episode 52 | steps=557 | ε=0.150 | reward=12.0
# Episode 53 | steps=566 | ε=0.150 | reward=9.0
# Episode 54 | steps=575 | ε=0.150 | reward=9.0
# Episode 55 | steps=583 | ε=0.150 | reward=8.0
# Episode 56 | steps=595 | ε=0.150 | reward=12.0
# Episode 57 | steps=604 | ε=0.150 | reward=9.0
# Episode 58 | steps=613 | ε=0.150 | reward=9.0
# Episode 59 | steps=623 | ε=0.150 | reward=10.0
# Episode 60 | steps=637 | ε=0.150 | reward=14.0
# Episode 61 | steps=649 | ε=0.150 | reward=12.0
# Episode 62 | steps=660 | ε=0.150 | reward=11.0
# Episode 63 | steps=669 | ε=0.150 | reward=9.0
# Episode 64 | steps=681 | ε=0.150 | reward=12.0
# Episode 65 | steps=691 | ε=0.150 | reward=10.0
# Episode 66 | steps=701 | ε=0.150 | reward=10.0
# Episode 67 | steps=715 | ε=0.150 | reward=14.0
# Episode 68 | steps=726 | ε=0.150 | reward=11.0
# Episode 69 | steps=737 | ε=0.150 | reward=11.0
# Episode 70 | steps=747 | ε=0.150 | reward=10.0
# Episode 71 | steps=758 | ε=0.150 | reward=11.0
# Episode 72 | steps=768 | ε=0.150 | reward=10.0
# Episode 73 | steps=778 | ε=0.150 | reward=10.0
# Episode 74 | steps=787 | ε=0.150 | reward=9.0
# Episode 75 | steps=797 | ε=0.150 | reward=10.0
# Episode 76 | steps=807 | ε=0.150 | reward=10.0
# Episode 77 | steps=817 | ε=0.150 | reward=10.0
# Episode 78 | steps=828 | ε=0.150 | reward=11.0
# Episode 79 | steps=840 | ε=0.150 | reward=12.0
# Episode 80 | steps=850 | ε=0.150 | reward=10.0
# Episode 81 | steps=859 | ε=0.150 | reward=9.0
# Episode 82 | steps=871 | ε=0.150 | reward=12.0
# Episode 83 | steps=880 | ε=0.150 | reward=9.0
# Episode 84 | steps=889 | ε=0.150 | reward=9.0
# Episode 85 | steps=899 | ε=0.150 | reward=10.0
# Episode 86 | steps=909 | ε=0.150 | reward=10.0
# Episode 87 | steps=917 | ε=0.150 | reward=8.0
# Episode 88 | steps=927 | ε=0.150 | reward=10.0
# Episode 89 | steps=935 | ε=0.150 | reward=8.0
# Episode 90 | steps=944 | ε=0.150 | reward=9.0
# Episode 91 | steps=956 | ε=0.150 | reward=12.0
# Episode 92 | steps=968 | ε=0.150 | reward=12.0
# Episode 93 | steps=977 | ε=0.150 | reward=9.0
# Episode 94 | steps=987 | ε=0.150 | reward=10.0
# Episode 95 | steps=997 | ε=0.150 | reward=10.0
# Episode 96 | steps=1007 | ε=0.150 | reward=10.0
# Episode 97 | steps=1018 | ε=0.150 | reward=11.0
# Episode 98 | steps=1030 | ε=0.150 | reward=12.0
# Episode 99 | steps=1040 | ε=0.150 | reward=10.0
# Episode 100 | steps=1050 | ε=0.150 | reward=10.0
# Episode 101 | steps=1061 | ε=0.150 | reward=11.0
# Episode 102 | steps=1070 | ε=0.150 | reward=9.0
# Episode 103 | steps=1080 | ε=0.150 | reward=10.0
# Episode 104 | steps=1090 | ε=0.150 | reward=10.0
# Episode 105 | steps=1101 | ε=0.150 | reward=11.0
# Episode 106 | steps=1113 | ε=0.150 | reward=12.0
# Episode 107 | steps=1125 | ε=0.150 | reward=12.0
# Episode 108 | steps=1134 | ε=0.150 | reward=9.0
# Episode 109 | steps=1144 | ε=0.150 | reward=10.0
# Episode 110 | steps=1154 | ε=0.150 | reward=10.0
# Episode 111 | steps=1164 | ε=0.150 | reward=10.0
# Episode 112 | steps=1173 | ε=0.150 | reward=9.0
# Episode 113 | steps=1182 | ε=0.150 | reward=9.0
# Episode 114 | steps=1191 | ε=0.150 | reward=9.0
# Episode 115 | steps=1199 | ε=0.150 | reward=8.0
# Episode 116 | steps=1209 | ε=0.150 | reward=10.0
# Episode 117 | steps=1222 | ε=0.150 | reward=13.0
# Episode 118 | steps=1233 | ε=0.150 | reward=11.0
# Episode 119 | steps=1243 | ε=0.150 | reward=10.0
# Episode 120 | steps=1255 | ε=0.150 | reward=12.0
# Episode 121 | steps=1265 | ε=0.150 | reward=10.0
# Episode 122 | steps=1277 | ε=0.150 | reward=12.0
# Episode 123 | steps=1289 | ε=0.150 | reward=12.0
# Episode 124 | steps=1298 | ε=0.150 | reward=9.0
# Episode 125 | steps=1307 | ε=0.150 | reward=9.0
# Episode 126 | steps=1318 | ε=0.150 | reward=11.0
# Episode 127 | steps=1331 | ε=0.150 | reward=13.0
# Episode 128 | steps=1340 | ε=0.150 | reward=9.0
# Episode 129 | steps=1351 | ε=0.150 | reward=11.0
# Episode 130 | steps=1362 | ε=0.150 | reward=11.0
# Episode 131 | steps=1372 | ε=0.150 | reward=10.0
# Episode 132 | steps=1382 | ε=0.150 | reward=10.0
# Episode 133 | steps=1393 | ε=0.150 | reward=11.0
# Episode 134 | steps=1402 | ε=0.150 | reward=9.0
# Episode 135 | steps=1411 | ε=0.150 | reward=9.0
# Episode 136 | steps=1420 | ε=0.150 | reward=9.0
# Episode 137 | steps=1429 | ε=0.150 | reward=9.0
# Episode 138 | steps=1438 | ε=0.150 | reward=9.0
# Episode 139 | steps=1448 | ε=0.150 | reward=10.0
# Episode 140 | steps=1457 | ε=0.150 | reward=9.0
# Episode 141 | steps=1467 | ε=0.150 | reward=10.0
# Episode 142 | steps=1476 | ε=0.150 | reward=9.0
# Episode 143 | steps=1486 | ε=0.150 | reward=10.0
# Episode 144 | steps=1494 | ε=0.150 | reward=8.0
# Episode 145 | steps=1508 | ε=0.150 | reward=14.0
# Episode 146 | steps=1517 | ε=0.150 | reward=9.0
# Episode 147 | steps=1526 | ε=0.150 | reward=9.0
# Episode 148 | steps=1538 | ε=0.150 | reward=12.0
# Episode 149 | steps=1546 | ε=0.150 | reward=8.0
# Episode 150 | steps=1557 | ε=0.150 | reward=11.0
# Episode 151 | steps=1567 | ε=0.150 | reward=10.0
# Episode 152 | steps=1576 | ε=0.150 | reward=9.0
# Episode 153 | steps=1585 | ε=0.150 | reward=9.0
# Episode 154 | steps=1594 | ε=0.150 | reward=9.0
# Episode 155 | steps=1604 | ε=0.150 | reward=10.0
# Episode 156 | steps=1615 | ε=0.150 | reward=11.0
# Episode 157 | steps=1625 | ε=0.150 | reward=10.0
# Episode 158 | steps=1633 | ε=0.150 | reward=8.0
# Episode 159 | steps=1641 | ε=0.150 | reward=8.0
# Episode 160 | steps=1650 | ε=0.150 | reward=9.0
# Episode 161 | steps=1660 | ε=0.150 | reward=10.0
# Episode 162 | steps=1669 | ε=0.150 | reward=9.0
# Episode 163 | steps=1679 | ε=0.150 | reward=10.0
# Episode 164 | steps=1695 | ε=0.150 | reward=16.0
# Episode 165 | steps=1705 | ε=0.150 | reward=10.0
# Episode 166 | steps=1714 | ε=0.150 | reward=9.0
# Episode 167 | steps=1726 | ε=0.150 | reward=12.0
# Episode 168 | steps=1740 | ε=0.150 | reward=14.0
# Episode 169 | steps=1751 | ε=0.150 | reward=11.0
# Episode 170 | steps=1761 | ε=0.150 | reward=10.0
# Episode 171 | steps=1771 | ε=0.150 | reward=10.0
# Episode 172 | steps=1784 | ε=0.150 | reward=13.0
# Episode 173 | steps=1793 | ε=0.150 | reward=9.0
# Episode 174 | steps=1802 | ε=0.150 | reward=9.0
# Episode 175 | steps=1813 | ε=0.150 | reward=11.0
# Episode 176 | steps=1823 | ε=0.150 | reward=10.0
# Episode 177 | steps=1832 | ε=0.150 | reward=9.0
# Episode 178 | steps=1842 | ε=0.150 | reward=10.0
# Episode 179 | steps=1853 | ε=0.150 | reward=11.0
# Episode 180 | steps=1864 | ε=0.150 | reward=11.0
# Episode 181 | steps=1875 | ε=0.150 | reward=11.0
# Episode 182 | steps=1887 | ε=0.150 | reward=12.0
# Episode 183 | steps=1898 | ε=0.150 | reward=11.0
# Episode 184 | steps=1908 | ε=0.150 | reward=10.0
# Episode 185 | steps=1917 | ε=0.150 | reward=9.0
# Episode 186 | steps=1928 | ε=0.150 | reward=11.0
# Episode 187 | steps=1938 | ε=0.150 | reward=10.0
# Episode 188 | steps=1947 | ε=0.150 | reward=9.0
# Episode 189 | steps=1963 | ε=0.150 | reward=16.0
# Episode 190 | steps=1973 | ε=0.150 | reward=10.0
# Episode 191 | steps=1985 | ε=0.150 | reward=12.0
# Episode 192 | steps=1994 | ε=0.150 | reward=9.0
# Episode 193 | steps=2003 | ε=0.150 | reward=9.0
# Episode 194 | steps=2014 | ε=0.150 | reward=11.0
# Episode 195 | steps=2024 | ε=0.150 | reward=10.0
# Episode 196 | steps=2038 | ε=0.150 | reward=14.0
# Episode 197 | steps=2048 | ε=0.150 | reward=10.0
# Episode 198 | steps=2057 | ε=0.150 | reward=9.0
# Episode 199 | steps=2066 | ε=0.150 | reward=9.0
# Episode 200 | steps=2078 | ε=0.150 | reward=12.0
# Episode 201 | steps=2089 | ε=0.150 | reward=11.0
# Episode 202 | steps=2100 | ε=0.150 | reward=11.0
# Episode 203 | steps=2108 | ε=0.150 | reward=8.0
# Episode 204 | steps=2119 | ε=0.150 | reward=11.0
# Episode 205 | steps=2128 | ε=0.150 | reward=9.0
# Episode 206 | steps=2139 | ε=0.150 | reward=11.0
# Episode 207 | steps=2151 | ε=0.150 | reward=12.0
# Episode 208 | steps=2164 | ε=0.150 | reward=13.0
# Episode 209 | steps=2175 | ε=0.150 | reward=11.0
# Episode 210 | steps=2185 | ε=0.150 | reward=10.0
# Episode 211 | steps=2195 | ε=0.150 | reward=10.0
# Episode 212 | steps=2204 | ε=0.150 | reward=9.0
# Episode 213 | steps=2214 | ε=0.150 | reward=10.0
# Episode 214 | steps=2224 | ε=0.150 | reward=10.0
# Episode 215 | steps=2234 | ε=0.150 | reward=10.0
# Episode 216 | steps=2245 | ε=0.150 | reward=11.0
# Episode 217 | steps=2255 | ε=0.150 | reward=10.0
# Episode 218 | steps=2264 | ε=0.150 | reward=9.0
# Episode 219 | steps=2272 | ε=0.150 | reward=8.0
# Episode 220 | steps=2284 | ε=0.150 | reward=12.0
# Episode 221 | steps=2294 | ε=0.150 | reward=10.0
# Episode 222 | steps=2303 | ε=0.150 | reward=9.0
# Episode 223 | steps=2318 | ε=0.150 | reward=15.0
# Episode 224 | steps=2327 | ε=0.150 | reward=9.0
# Episode 225 | steps=2336 | ε=0.150 | reward=9.0
# Episode 226 | steps=2346 | ε=0.150 | reward=10.0
# Episode 227 | steps=2355 | ε=0.150 | reward=9.0
# Episode 228 | steps=2364 | ε=0.150 | reward=9.0
# Episode 229 | steps=2374 | ε=0.150 | reward=10.0
# Episode 230 | steps=2384 | ε=0.150 | reward=10.0
# Episode 231 | steps=2394 | ε=0.150 | reward=10.0
# Episode 232 | steps=2404 | ε=0.150 | reward=10.0
# Episode 233 | steps=2413 | ε=0.150 | reward=9.0
# Episode 234 | steps=2428 | ε=0.150 | reward=15.0
# Episode 235 | steps=2437 | ε=0.150 | reward=9.0
# Episode 236 | steps=2447 | ε=0.150 | reward=10.0
# Episode 237 | steps=2459 | ε=0.150 | reward=12.0
# Episode 238 | steps=2468 | ε=0.150 | reward=9.0
# Episode 239 | steps=2477 | ε=0.150 | reward=9.0
# Episode 240 | steps=2488 | ε=0.150 | reward=11.0
# Episode 241 | steps=2497 | ε=0.150 | reward=9.0
# Episode 242 | steps=2506 | ε=0.150 | reward=9.0
# Episode 243 | steps=2517 | ε=0.150 | reward=11.0
# Episode 244 | steps=2527 | ε=0.150 | reward=10.0
# Episode 245 | steps=2536 | ε=0.150 | reward=9.0
# Episode 246 | steps=2546 | ε=0.150 | reward=10.0
# Episode 247 | steps=2556 | ε=0.150 | reward=10.0
# Episode 248 | steps=2568 | ε=0.150 | reward=12.0
# Episode 249 | steps=2580 | ε=0.150 | reward=12.0
# Episode 250 | steps=2590 | ε=0.150 | reward=10.0
# Episode 251 | steps=2601 | ε=0.150 | reward=11.0
# Episode 252 | steps=2610 | ε=0.150 | reward=9.0
# Episode 253 | steps=2619 | ε=0.150 | reward=9.0
# Episode 254 | steps=2630 | ε=0.150 | reward=11.0
# Episode 255 | steps=2642 | ε=0.150 | reward=12.0
# Episode 256 | steps=2655 | ε=0.150 | reward=13.0
# Episode 257 | steps=2664 | ε=0.150 | reward=9.0
# Episode 258 | steps=2673 | ε=0.150 | reward=9.0
# Episode 259 | steps=2684 | ε=0.150 | reward=11.0
# Episode 260 | steps=2694 | ε=0.150 | reward=10.0
# Episode 261 | steps=2703 | ε=0.150 | reward=9.0
# Episode 262 | steps=2713 | ε=0.150 | reward=10.0
# Episode 263 | steps=2722 | ε=0.150 | reward=9.0
# Episode 264 | steps=2732 | ε=0.150 | reward=10.0
# Episode 265 | steps=2743 | ε=0.150 | reward=11.0
# Episode 266 | steps=2754 | ε=0.150 | reward=11.0
# Episode 267 | steps=2767 | ε=0.150 | reward=13.0
# Episode 268 | steps=2781 | ε=0.150 | reward=14.0
# Episode 269 | steps=2795 | ε=0.150 | reward=14.0
# Episode 270 | steps=2806 | ε=0.150 | reward=11.0
# Episode 271 | steps=2822 | ε=0.150 | reward=16.0
# Episode 272 | steps=2883 | ε=0.150 | reward=61.0
# Episode 273 | steps=2909 | ε=0.150 | reward=26.0
# Episode 274 | steps=2989 | ε=0.150 | reward=80.0
# Episode 275 | steps=3085 | ε=0.150 | reward=96.0
# Episode 276 | steps=3196 | ε=0.150 | reward=111.0
# Episode 277 | steps=3248 | ε=0.150 | reward=52.0
# Episode 278 | steps=3297 | ε=0.150 | reward=49.0
# Episode 279 | steps=3355 | ε=0.150 | reward=58.0
# Episode 280 | steps=3402 | ε=0.150 | reward=47.0
# Episode 281 | steps=3489 | ε=0.150 | reward=87.0
# Episode 282 | steps=3540 | ε=0.150 | reward=51.0
# Episode 283 | steps=3571 | ε=0.150 | reward=31.0
# Episode 284 | steps=3704 | ε=0.150 | reward=133.0
# Episode 285 | steps=3782 | ε=0.150 | reward=78.0
# Episode 286 | steps=3837 | ε=0.150 | reward=55.0
# Episode 287 | steps=3875 | ε=0.150 | reward=38.0
# Episode 288 | steps=3932 | ε=0.150 | reward=57.0
# Episode 289 | steps=3983 | ε=0.150 | reward=51.0
# Episode 290 | steps=4017 | ε=0.150 | reward=34.0
# Episode 291 | steps=4073 | ε=0.150 | reward=56.0
# Episode 292 | steps=4139 | ε=0.150 | reward=66.0
# Episode 293 | steps=4201 | ε=0.150 | reward=62.0
# Episode 294 | steps=4250 | ε=0.150 | reward=49.0
# Episode 295 | steps=4298 | ε=0.150 | reward=48.0
# Episode 296 | steps=4370 | ε=0.150 | reward=72.0
# Episode 297 | steps=4475 | ε=0.150 | reward=105.0
# Episode 298 | steps=4550 | ε=0.150 | reward=75.0
# Episode 299 | steps=4627 | ε=0.150 | reward=77.0
# Episode 300 | steps=4721 | ε=0.150 | reward=94.0
# Episode 301 | steps=4757 | ε=0.150 | reward=36.0
# Episode 302 | steps=4802 | ε=0.150 | reward=45.0
# Episode 303 | steps=4833 | ε=0.150 | reward=31.0
# Episode 304 | steps=4881 | ε=0.150 | reward=48.0
# Episode 305 | steps=4941 | ε=0.150 | reward=60.0
# Episode 306 | steps=5010 | ε=0.150 | reward=69.0
# Episode 307 | steps=5073 | ε=0.150 | reward=63.0
# Episode 308 | steps=5202 | ε=0.150 | reward=129.0
# Episode 309 | steps=5276 | ε=0.150 | reward=74.0
# Episode 310 | steps=5319 | ε=0.150 | reward=43.0
# Episode 311 | steps=5398 | ε=0.150 | reward=79.0
# Episode 312 | steps=5447 | ε=0.150 | reward=49.0
# Episode 313 | steps=5487 | ε=0.150 | reward=40.0
# Episode 314 | steps=5527 | ε=0.150 | reward=40.0
# Episode 315 | steps=5568 | ε=0.150 | reward=41.0
# Episode 316 | steps=5619 | ε=0.150 | reward=51.0
# Episode 317 | steps=5744 | ε=0.150 | reward=125.0
# Episode 318 | steps=5803 | ε=0.150 | reward=59.0
# Episode 319 | steps=5874 | ε=0.150 | reward=71.0
# Episode 320 | steps=5917 | ε=0.150 | reward=43.0
# Episode 321 | steps=6004 | ε=0.150 | reward=87.0
# Episode 322 | steps=6077 | ε=0.150 | reward=73.0
# Episode 323 | steps=6151 | ε=0.150 | reward=74.0
# Episode 324 | steps=6193 | ε=0.150 | reward=42.0
# Episode 325 | steps=6241 | ε=0.150 | reward=48.0
# Episode 326 | steps=6304 | ε=0.150 | reward=63.0
# Episode 327 | steps=6385 | ε=0.150 | reward=81.0
# Episode 328 | steps=6438 | ε=0.150 | reward=53.0
# Episode 329 | steps=6502 | ε=0.150 | reward=64.0
# Episode 330 | steps=6568 | ε=0.150 | reward=66.0
# Episode 331 | steps=6679 | ε=0.150 | reward=111.0
# Episode 332 | steps=6821 | ε=0.150 | reward=142.0
# Episode 333 | steps=6910 | ε=0.150 | reward=89.0
# Episode 334 | steps=6999 | ε=0.150 | reward=89.0
# Episode 335 | steps=7111 | ε=0.150 | reward=112.0
# Episode 336 | steps=7225 | ε=0.150 | reward=114.0
# Episode 337 | steps=7356 | ε=0.150 | reward=131.0
# Episode 338 | steps=7436 | ε=0.150 | reward=80.0
# Episode 339 | steps=7669 | ε=0.150 | reward=233.0
# Episode 340 | steps=7770 | ε=0.150 | reward=101.0
# Episode 341 | steps=8037 | ε=0.150 | reward=267.0
# Episode 342 | steps=8107 | ε=0.150 | reward=70.0
# Episode 343 | steps=8196 | ε=0.150 | reward=89.0
# Episode 344 | steps=8322 | ε=0.150 | reward=126.0
# Episode 345 | steps=8499 | ε=0.150 | reward=177.0
# Episode 346 | steps=8760 | ε=0.150 | reward=261.0
# Episode 347 | steps=8928 | ε=0.150 | reward=168.0
# Episode 348 | steps=9320 | ε=0.150 | reward=392.0
# Episode 349 | steps=9665 | ε=0.150 | reward=345.0
# Episode 350 | steps=9884 | ε=0.150 | reward=219.0
# Episode 351 | steps=10192 | ε=0.150 | reward=308.0
# Episode 352 | steps=10453 | ε=0.150 | reward=261.0
# Episode 353 | steps=10726 | ε=0.150 | reward=273.0
# Episode 354 | steps=11196 | ε=0.150 | reward=470.0
# Episode 355 | steps=11425 | ε=0.150 | reward=229.0
# Episode 356 | steps=11677 | ε=0.150 | reward=252.0
# Episode 357 | steps=12110 | ε=0.150 | reward=433.0
# Episode 358 | steps=12296 | ε=0.150 | reward=186.0
# Episode 359 | steps=12632 | ε=0.150 | reward=336.0
# Episode 360 | steps=12912 | ε=0.150 | reward=280.0
# Episode 361 | steps=13212 | ε=0.150 | reward=300.0
# Episode 362 | steps=13429 | ε=0.150 | reward=217.0
# Episode 363 | steps=13624 | ε=0.150 | reward=195.0
# Episode 364 | steps=13853 | ε=0.150 | reward=229.0
# Episode 365 | steps=14055 | ε=0.150 | reward=202.0
# Episode 366 | steps=14253 | ε=0.150 | reward=198.0
# Episode 367 | steps=14438 | ε=0.150 | reward=185.0
# Episode 368 | steps=14695 | ε=0.150 | reward=257.0
# Episode 369 | steps=14914 | ε=0.150 | reward=219.0
# Episode 370 | steps=15088 | ε=0.150 | reward=174.0
# Episode 371 | steps=15284 | ε=0.150 | reward=196.0
# Episode 372 | steps=15487 | ε=0.150 | reward=203.0
# Episode 373 | steps=15670 | ε=0.150 | reward=183.0
# Episode 374 | steps=15848 | ε=0.150 | reward=178.0
# Episode 375 | steps=16027 | ε=0.150 | reward=179.0
# Episode 376 | steps=16300 | ε=0.150 | reward=273.0
# Episode 377 | steps=16496 | ε=0.150 | reward=196.0
# Episode 378 | steps=16732 | ε=0.150 | reward=236.0
# Episode 379 | steps=16957 | ε=0.150 | reward=225.0
# Episode 380 | steps=17154 | ε=0.150 | reward=197.0
# Episode 381 | steps=17338 | ε=0.150 | reward=184.0
# Episode 382 | steps=17682 | ε=0.150 | reward=344.0
# Episode 383 | steps=17936 | ε=0.150 | reward=254.0
# Episode 384 | steps=18219 | ε=0.150 | reward=283.0
# Episode 385 | steps=18421 | ε=0.150 | reward=202.0
# Episode 386 | steps=18680 | ε=0.150 | reward=259.0
# Episode 387 | steps=18968 | ε=0.150 | reward=288.0
# Episode 388 | steps=19468 | ε=0.150 | reward=500.0
# Episode 389 | steps=19764 | ε=0.150 | reward=296.0
# Episode 390 | steps=20127 | ε=0.150 | reward=363.0
# Episode 391 | steps=20461 | ε=0.150 | reward=334.0
# Episode 392 | steps=20691 | ε=0.150 | reward=230.0
# Episode 393 | steps=20965 | ε=0.150 | reward=274.0
# Episode 394 | steps=21274 | ε=0.150 | reward=309.0
# Episode 395 | steps=21554 | ε=0.150 | reward=280.0
# Episode 396 | steps=21849 | ε=0.150 | reward=295.0
# Episode 397 | steps=22250 | ε=0.150 | reward=401.0
# Episode 398 | steps=22518 | ε=0.150 | reward=268.0
# Episode 399 | steps=22895 | ε=0.150 | reward=377.0
# Episode 400 | steps=23172 | ε=0.150 | reward=277.0
# Episode 401 | steps=23379 | ε=0.150 | reward=207.0
# Episode 402 | steps=23674 | ε=0.150 | reward=295.0
# Episode 403 | steps=24041 | ε=0.150 | reward=367.0
# Episode 404 | steps=24413 | ε=0.150 | reward=372.0
# Episode 405 | steps=24692 | ε=0.150 | reward=279.0
# Episode 406 | steps=24952 | ε=0.150 | reward=260.0
# Episode 407 | steps=25231 | ε=0.150 | reward=279.0
# Episode 408 | steps=25480 | ε=0.150 | reward=249.0
# Episode 409 | steps=25713 | ε=0.150 | reward=233.0
# Episode 410 | steps=26135 | ε=0.150 | reward=422.0
# Episode 411 | steps=26371 | ε=0.150 | reward=236.0
# Episode 412 | steps=26638 | ε=0.150 | reward=267.0
# Episode 413 | steps=26848 | ε=0.150 | reward=210.0
# Episode 414 | steps=27133 | ε=0.150 | reward=285.0
# Episode 415 | steps=27569 | ε=0.150 | reward=436.0
# Episode 416 | steps=27818 | ε=0.150 | reward=249.0
# Episode 417 | steps=28012 | ε=0.150 | reward=194.0
# Episode 418 | steps=28316 | ε=0.150 | reward=304.0
# Episode 419 | steps=28515 | ε=0.150 | reward=199.0
# Episode 420 | steps=28762 | ε=0.150 | reward=247.0
# Episode 421 | steps=29004 | ε=0.150 | reward=242.0
# Episode 422 | steps=29272 | ε=0.150 | reward=268.0
# Episode 423 | steps=29587 | ε=0.150 | reward=315.0
# Episode 424 | steps=29838 | ε=0.150 | reward=251.0
# Episode 425 | steps=30042 | ε=0.150 | reward=204.0
# Episode 426 | steps=30418 | ε=0.150 | reward=376.0
# Episode 427 | steps=30715 | ε=0.150 | reward=297.0
# Episode 428 | steps=30948 | ε=0.150 | reward=233.0
# Episode 429 | steps=31167 | ε=0.150 | reward=219.0
# Episode 430 | steps=31387 | ε=0.150 | reward=220.0
# Episode 431 | steps=31642 | ε=0.150 | reward=255.0
# Episode 432 | steps=31924 | ε=0.150 | reward=282.0
# Episode 433 | steps=32132 | ε=0.150 | reward=208.0
# Episode 434 | steps=32351 | ε=0.150 | reward=219.0
# Episode 435 | steps=32541 | ε=0.150 | reward=190.0
# Episode 436 | steps=32753 | ε=0.150 | reward=212.0
# Episode 437 | steps=33010 | ε=0.150 | reward=257.0
# Episode 438 | steps=33246 | ε=0.150 | reward=236.0
# Episode 439 | steps=33632 | ε=0.150 | reward=386.0
# Episode 440 | steps=33934 | ε=0.150 | reward=302.0
# Episode 441 | steps=34152 | ε=0.150 | reward=218.0
# Episode 442 | steps=34355 | ε=0.150 | reward=203.0
# Episode 443 | steps=34568 | ε=0.150 | reward=213.0
# Episode 444 | steps=34785 | ε=0.150 | reward=217.0
# Episode 445 | steps=35054 | ε=0.150 | reward=269.0
# Episode 446 | steps=35279 | ε=0.150 | reward=225.0
# Episode 447 | steps=35676 | ε=0.150 | reward=397.0
# Episode 448 | steps=36009 | ε=0.150 | reward=333.0
# Episode 449 | steps=36206 | ε=0.150 | reward=197.0
# Episode 450 | steps=36450 | ε=0.150 | reward=244.0
# Episode 451 | steps=36629 | ε=0.150 | reward=179.0
# Episode 452 | steps=36825 | ε=0.150 | reward=196.0
# Episode 453 | steps=37095 | ε=0.150 | reward=270.0
# Episode 454 | steps=37307 | ε=0.150 | reward=212.0
# Episode 455 | steps=37521 | ε=0.150 | reward=214.0
# Episode 456 | steps=37746 | ε=0.150 | reward=225.0
# Episode 457 | steps=37834 | ε=0.150 | reward=88.0
# Episode 458 | steps=38031 | ε=0.150 | reward=197.0
# Episode 459 | steps=38298 | ε=0.150 | reward=267.0
# Episode 460 | steps=38511 | ε=0.150 | reward=213.0
# Episode 461 | steps=38746 | ε=0.150 | reward=235.0
# Episode 462 | steps=38975 | ε=0.150 | reward=229.0
# Episode 463 | steps=39248 | ε=0.150 | reward=273.0
# Episode 464 | steps=39503 | ε=0.150 | reward=255.0
# Episode 465 | steps=39731 | ε=0.150 | reward=228.0
# Episode 466 | steps=39920 | ε=0.150 | reward=189.0
# Episode 467 | steps=40190 | ε=0.150 | reward=270.0
# Episode 468 | steps=40412 | ε=0.150 | reward=222.0
# Episode 469 | steps=40482 | ε=0.150 | reward=70.0
# Episode 470 | steps=40832 | ε=0.150 | reward=350.0
# Episode 471 | steps=41053 | ε=0.150 | reward=221.0
# Episode 472 | steps=41252 | ε=0.150 | reward=199.0
# Episode 473 | steps=41464 | ε=0.150 | reward=212.0
# Episode 474 | steps=41707 | ε=0.150 | reward=243.0
# Episode 475 | steps=41951 | ε=0.150 | reward=244.0
# Episode 476 | steps=42170 | ε=0.150 | reward=219.0
# Episode 477 | steps=42469 | ε=0.150 | reward=299.0
# Episode 478 | steps=42697 | ε=0.150 | reward=228.0
# Episode 479 | steps=42901 | ε=0.150 | reward=204.0
# Episode 480 | steps=43193 | ε=0.150 | reward=292.0
# Episode 481 | steps=43432 | ε=0.150 | reward=239.0
# Episode 482 | steps=43609 | ε=0.150 | reward=177.0
# Episode 483 | steps=43807 | ε=0.150 | reward=198.0
# Episode 484 | steps=44031 | ε=0.150 | reward=224.0
# Episode 485 | steps=44225 | ε=0.150 | reward=194.0
# Episode 486 | steps=44462 | ε=0.150 | reward=237.0
# Episode 487 | steps=44673 | ε=0.150 | reward=211.0
# Episode 488 | steps=44924 | ε=0.150 | reward=251.0
# Episode 489 | steps=45149 | ε=0.150 | reward=225.0
# Episode 490 | steps=45375 | ε=0.150 | reward=226.0
# Episode 491 | steps=45605 | ε=0.150 | reward=230.0
# Episode 492 | steps=45803 | ε=0.150 | reward=198.0
# Episode 493 | steps=45971 | ε=0.150 | reward=168.0
# Episode 494 | steps=46190 | ε=0.150 | reward=219.0
# Episode 495 | steps=46401 | ε=0.150 | reward=211.0
# Episode 496 | steps=46619 | ε=0.150 | reward=218.0
# Episode 497 | steps=46889 | ε=0.150 | reward=270.0
# Episode 498 | steps=47101 | ε=0.150 | reward=212.0
# Episode 499 | steps=47314 | ε=0.150 | reward=213.0
# Episode 500 | steps=47483 | ε=0.150 | reward=169.0
# Episode 501 | steps=47728 | ε=0.150 | reward=245.0
# Episode 502 | steps=47927 | ε=0.150 | reward=199.0
# Episode 503 | steps=48126 | ε=0.150 | reward=199.0
# Episode 504 | steps=48325 | ε=0.150 | reward=199.0
# Episode 505 | steps=48509 | ε=0.150 | reward=184.0
# Episode 506 | steps=48671 | ε=0.150 | reward=162.0
# Episode 507 | steps=48842 | ε=0.150 | reward=171.0
# Episode 508 | steps=49042 | ε=0.150 | reward=200.0
# Episode 509 | steps=49254 | ε=0.150 | reward=212.0
# Episode 510 | steps=49452 | ε=0.150 | reward=198.0
# Episode 511 | steps=49621 | ε=0.150 | reward=169.0
# Episode 512 | steps=49814 | ε=0.150 | reward=193.0
# Episode 513 | steps=50023 | ε=0.150 | reward=209.0
# Episode 514 | steps=50212 | ε=0.150 | reward=189.0
# Episode 515 | steps=50405 | ε=0.150 | reward=193.0
# Episode 516 | steps=50602 | ε=0.150 | reward=197.0
# Episode 517 | steps=50844 | ε=0.150 | reward=242.0
# Episode 518 | steps=51051 | ε=0.150 | reward=207.0
# Episode 519 | steps=51245 | ε=0.150 | reward=194.0
# Episode 520 | steps=51465 | ε=0.150 | reward=220.0
# Episode 521 | steps=51652 | ε=0.150 | reward=187.0
# Episode 522 | steps=51848 | ε=0.150 | reward=196.0
# Episode 523 | steps=52079 | ε=0.150 | reward=231.0
# Episode 524 | steps=52270 | ε=0.150 | reward=191.0
# Episode 525 | steps=52466 | ε=0.150 | reward=196.0
# Episode 526 | steps=52665 | ε=0.150 | reward=199.0
# Episode 527 | steps=52864 | ε=0.150 | reward=199.0
# Episode 528 | steps=53178 | ε=0.150 | reward=314.0
# Episode 529 | steps=53357 | ε=0.150 | reward=179.0
# Episode 530 | steps=53588 | ε=0.150 | reward=231.0
# Episode 531 | steps=53788 | ε=0.150 | reward=200.0
# Episode 532 | steps=53966 | ε=0.150 | reward=178.0
# Episode 533 | steps=54178 | ε=0.150 | reward=212.0
# Episode 534 | steps=54375 | ε=0.150 | reward=197.0
# Episode 535 | steps=54582 | ε=0.150 | reward=207.0
# Episode 536 | steps=54824 | ε=0.150 | reward=242.0
# Episode 537 | steps=55047 | ε=0.150 | reward=223.0
# Episode 538 | steps=55249 | ε=0.150 | reward=202.0
# Episode 539 | steps=55428 | ε=0.150 | reward=179.0
# Episode 540 | steps=55648 | ε=0.150 | reward=220.0
# Episode 541 | steps=55840 | ε=0.150 | reward=192.0
# Episode 542 | steps=56119 | ε=0.150 | reward=279.0
# Episode 543 | steps=56354 | ε=0.150 | reward=235.0
# Episode 544 | steps=56554 | ε=0.150 | reward=200.0
# Episode 545 | steps=56751 | ε=0.150 | reward=197.0
# Episode 546 | steps=56953 | ε=0.150 | reward=202.0
# Episode 547 | steps=57141 | ε=0.150 | reward=188.0
# Episode 548 | steps=57404 | ε=0.150 | reward=263.0
# Episode 549 | steps=57637 | ε=0.150 | reward=233.0
# Episode 550 | steps=57850 | ε=0.150 | reward=213.0
# Episode 551 | steps=58002 | ε=0.150 | reward=152.0
# Episode 552 | steps=58257 | ε=0.150 | reward=255.0
# Episode 553 | steps=58462 | ε=0.150 | reward=205.0
# Episode 554 | steps=58734 | ε=0.150 | reward=272.0
# Episode 555 | steps=58961 | ε=0.150 | reward=227.0
# Episode 556 | steps=59166 | ε=0.150 | reward=205.0
# Episode 557 | steps=59373 | ε=0.150 | reward=207.0
# Episode 558 | steps=59611 | ε=0.150 | reward=238.0
# Episode 559 | steps=59815 | ε=0.150 | reward=204.0
# Episode 560 | steps=60060 | ε=0.150 | reward=245.0
# Episode 561 | steps=60236 | ε=0.150 | reward=176.0
# Episode 562 | steps=60411 | ε=0.150 | reward=175.0
# Episode 563 | steps=60456 | ε=0.150 | reward=45.0
# Episode 564 | steps=60625 | ε=0.150 | reward=169.0
# Episode 565 | steps=60881 | ε=0.150 | reward=256.0
# Episode 566 | steps=61237 | ε=0.150 | reward=356.0
# Episode 567 | steps=61428 | ε=0.150 | reward=191.0
# Episode 568 | steps=61628 | ε=0.150 | reward=200.0
# Episode 569 | steps=61843 | ε=0.150 | reward=215.0
# Episode 570 | steps=62096 | ε=0.150 | reward=253.0
# Episode 571 | steps=62331 | ε=0.150 | reward=235.0
# Episode 572 | steps=62547 | ε=0.150 | reward=216.0
# Episode 573 | steps=62768 | ε=0.150 | reward=221.0
# Episode 574 | steps=62997 | ε=0.150 | reward=229.0
# Episode 575 | steps=63257 | ε=0.150 | reward=260.0
# Episode 576 | steps=63442 | ε=0.150 | reward=185.0
# Episode 577 | steps=63724 | ε=0.150 | reward=282.0
# Episode 578 | steps=63962 | ε=0.150 | reward=238.0
# Episode 579 | steps=64203 | ε=0.150 | reward=241.0
# Episode 580 | steps=64392 | ε=0.150 | reward=189.0
# Episode 581 | steps=64627 | ε=0.150 | reward=235.0
# Episode 582 | steps=64875 | ε=0.150 | reward=248.0
# Episode 583 | steps=65142 | ε=0.150 | reward=267.0
# Episode 584 | steps=65353 | ε=0.150 | reward=211.0
# Episode 585 | steps=65657 | ε=0.150 | reward=304.0
# Episode 586 | steps=65875 | ε=0.150 | reward=218.0
# Episode 587 | steps=66142 | ε=0.150 | reward=267.0
# Episode 588 | steps=66340 | ε=0.150 | reward=198.0
# Episode 589 | steps=66590 | ε=0.150 | reward=250.0
# Episode 590 | steps=66857 | ε=0.150 | reward=267.0
# Episode 591 | steps=67063 | ε=0.150 | reward=206.0
# Episode 592 | steps=67355 | ε=0.150 | reward=292.0
# Episode 593 | steps=67587 | ε=0.150 | reward=232.0
# Episode 594 | steps=67780 | ε=0.150 | reward=193.0
# Episode 595 | steps=67893 | ε=0.150 | reward=113.0
# Episode 596 | steps=68178 | ε=0.150 | reward=285.0
# Episode 597 | steps=68414 | ε=0.150 | reward=236.0
# Episode 598 | steps=68653 | ε=0.150 | reward=239.0
# Episode 599 | steps=68997 | ε=0.150 | reward=344.0
# Episode 600 | steps=69252 | ε=0.150 | reward=255.0
# Episode 601 | steps=69513 | ε=0.150 | reward=261.0
# Episode 602 | steps=69751 | ε=0.150 | reward=238.0
# Episode 603 | steps=70118 | ε=0.150 | reward=367.0
# Episode 604 | steps=70315 | ε=0.150 | reward=197.0
# Episode 605 | steps=70748 | ε=0.150 | reward=433.0
# Episode 606 | steps=70981 | ε=0.150 | reward=233.0
# Episode 607 | steps=71274 | ε=0.150 | reward=293.0
# Episode 608 | steps=71584 | ε=0.150 | reward=310.0
# Episode 609 | steps=71936 | ε=0.150 | reward=352.0
# Episode 610 | steps=72302 | ε=0.150 | reward=366.0
# Episode 611 | steps=72606 | ε=0.150 | reward=304.0
# Episode 612 | steps=72899 | ε=0.150 | reward=293.0
# Episode 613 | steps=73177 | ε=0.150 | reward=278.0
# Episode 614 | steps=73392 | ε=0.150 | reward=215.0
# Episode 615 | steps=73811 | ε=0.150 | reward=419.0
# Episode 616 | steps=74231 | ε=0.150 | reward=420.0
# Episode 617 | steps=74587 | ε=0.150 | reward=356.0
# Episode 618 | steps=75004 | ε=0.150 | reward=417.0
# Episode 619 | steps=75338 | ε=0.150 | reward=334.0
# Episode 620 | steps=75748 | ε=0.150 | reward=410.0
# Episode 621 | steps=76052 | ε=0.150 | reward=304.0
# Episode 622 | steps=76294 | ε=0.150 | reward=242.0
# Episode 623 | steps=76602 | ε=0.150 | reward=308.0
# Episode 624 | steps=76918 | ε=0.150 | reward=316.0
# Episode 625 | steps=77388 | ε=0.150 | reward=470.0
# Episode 626 | steps=77888 | ε=0.150 | reward=500.0
# Episode 627 | steps=78234 | ε=0.150 | reward=346.0
# Episode 628 | steps=78548 | ε=0.150 | reward=314.0
# Episode 629 | steps=78849 | ε=0.150 | reward=301.0
# Episode 630 | steps=79349 | ε=0.150 | reward=500.0
# Episode 631 | steps=79849 | ε=0.150 | reward=500.0
# Episode 632 | steps=80270 | ε=0.150 | reward=421.0
# Episode 633 | steps=80770 | ε=0.150 | reward=500.0
# Episode 634 | steps=81061 | ε=0.150 | reward=291.0
# Episode 635 | steps=81396 | ε=0.150 | reward=335.0
# Episode 636 | steps=81683 | ε=0.150 | reward=287.0
# Episode 637 | steps=82183 | ε=0.150 | reward=500.0
# Episode 638 | steps=82508 | ε=0.150 | reward=325.0
# Episode 639 | steps=83008 | ε=0.150 | reward=500.0
# Episode 640 | steps=83508 | ε=0.150 | reward=500.0
# Episode 641 | steps=83891 | ε=0.150 | reward=383.0
# Episode 642 | steps=84391 | ε=0.150 | reward=500.0
# Episode 643 | steps=84891 | ε=0.150 | reward=500.0
# Episode 644 | steps=85391 | ε=0.150 | reward=500.0
# Episode 645 | steps=85879 | ε=0.150 | reward=488.0
# Episode 646 | steps=86379 | ε=0.150 | reward=500.0
# Episode 647 | steps=86879 | ε=0.150 | reward=500.0
# Episode 648 | steps=87379 | ε=0.150 | reward=500.0
# Episode 649 | steps=87879 | ε=0.150 | reward=500.0
# Episode 650 | steps=88379 | ε=0.150 | reward=500.0
# Episode 651 | steps=88879 | ε=0.150 | reward=500.0
# Episode 652 | steps=89379 | ε=0.150 | reward=500.0
# Episode 653 | steps=89879 | ε=0.150 | reward=500.0
# Episode 654 | steps=90379 | ε=0.150 | reward=500.0
# Episode 655 | steps=90879 | ε=0.150 | reward=500.0
# Episode 656 | steps=91377 | ε=0.150 | reward=498.0
# Episode 657 | steps=91720 | ε=0.150 | reward=343.0
# Episode 658 | steps=92220 | ε=0.150 | reward=500.0
# Episode 659 | steps=92720 | ε=0.150 | reward=500.0
# Episode 660 | steps=93220 | ε=0.150 | reward=500.0
# Episode 661 | steps=93720 | ε=0.150 | reward=500.0
# Episode 662 | steps=94220 | ε=0.150 | reward=500.0
# Episode 663 | steps=94720 | ε=0.150 | reward=500.0
# Episode 664 | steps=95220 | ε=0.150 | reward=500.0
# Episode 665 | steps=95720 | ε=0.150 | reward=500.0
# Episode 666 | steps=96220 | ε=0.150 | reward=500.0
# Episode 667 | steps=96720 | ε=0.150 | reward=500.0
# Episode 668 | steps=97220 | ε=0.150 | reward=500.0
# Episode 669 | steps=97720 | ε=0.150 | reward=500.0
# Episode 670 | steps=98220 | ε=0.150 | reward=500.0
# Episode 671 | steps=98720 | ε=0.150 | reward=500.0
# Episode 672 | steps=99220 | ε=0.150 | reward=500.0
# Episode 673 | steps=99720 | ε=0.150 | reward=500.0
# Episode 674 | steps=100220 | ε=0.150 | reward=500.0
# Episode 675 | steps=100720 | ε=0.150 | reward=500.0
# Episode 676 | steps=101220 | ε=0.150 | reward=500.0
# Episode 677 | steps=101720 | ε=0.150 | reward=500.0
# Episode 678 | steps=102220 | ε=0.150 | reward=500.0
# Episode 679 | steps=102720 | ε=0.150 | reward=500.0
# Episode 680 | steps=103220 | ε=0.150 | reward=500.0
# Episode 681 | steps=103720 | ε=0.150 | reward=500.0
# Episode 682 | steps=104220 | ε=0.150 | reward=500.0
# Episode 683 | steps=104720 | ε=0.150 | reward=500.0
# Episode 684 | steps=105220 | ε=0.150 | reward=500.0
# Episode 685 | steps=105249 | ε=0.150 | reward=29.0
# Episode 686 | steps=105749 | ε=0.150 | reward=500.0
# Episode 687 | steps=106249 | ε=0.150 | reward=500.0
# Episode 688 | steps=106749 | ε=0.150 | reward=500.0
# Episode 689 | steps=107249 | ε=0.150 | reward=500.0
# Episode 690 | steps=107749 | ε=0.150 | reward=500.0
# Episode 691 | steps=108249 | ε=0.150 | reward=500.0
# Episode 692 | steps=108749 | ε=0.150 | reward=500.0
# Episode 693 | steps=109249 | ε=0.150 | reward=500.0
# Episode 694 | steps=109749 | ε=0.150 | reward=500.0
# Episode 695 | steps=110249 | ε=0.150 | reward=500.0
# Episode 696 | steps=110749 | ε=0.150 | reward=500.0
# Episode 697 | steps=111249 | ε=0.150 | reward=500.0
# Episode 698 | steps=111749 | ε=0.150 | reward=500.0
# Episode 699 | steps=112249 | ε=0.150 | reward=500.0
# Episode 700 | steps=112749 | ε=0.150 | reward=500.0
# Episode 701 | steps=113249 | ε=0.150 | reward=500.0
# Episode 702 | steps=113749 | ε=0.150 | reward=500.0
# Episode 703 | steps=114249 | ε=0.150 | reward=500.0
# Episode 704 | steps=114749 | ε=0.150 | reward=500.0
# Episode 705 | steps=115249 | ε=0.150 | reward=500.0
# Episode 706 | steps=115749 | ε=0.150 | reward=500.0
# Episode 707 | steps=116249 | ε=0.150 | reward=500.0
# Episode 708 | steps=116749 | ε=0.150 | reward=500.0
# Episode 709 | steps=117249 | ε=0.150 | reward=500.0
# Episode 710 | steps=117749 | ε=0.150 | reward=500.0
# Episode 711 | steps=118249 | ε=0.150 | reward=500.0
# Episode 712 | steps=118749 | ε=0.150 | reward=500.0
# Episode 713 | steps=119249 | ε=0.150 | reward=500.0
# Episode 714 | steps=119470 | ε=0.150 | reward=221.0
# Episode 715 | steps=119970 | ε=0.150 | reward=500.0
# Episode 716 | steps=120470 | ε=0.150 | reward=500.0
# Episode 717 | steps=120970 | ε=0.150 | reward=500.0
# Episode 718 | steps=121470 | ε=0.150 | reward=500.0
# Episode 719 | steps=121970 | ε=0.150 | reward=500.0
# Episode 720 | steps=122470 | ε=0.150 | reward=500.0
# Episode 721 | steps=122970 | ε=0.150 | reward=500.0
# Episode 722 | steps=123366 | ε=0.150 | reward=396.0
# Episode 723 | steps=123866 | ε=0.150 | reward=500.0
# Episode 724 | steps=123953 | ε=0.150 | reward=87.0
# Episode 725 | steps=124453 | ε=0.150 | reward=500.0
# Episode 726 | steps=124953 | ε=0.150 | reward=500.0
# Episode 727 | steps=125335 | ε=0.150 | reward=382.0
# Episode 728 | steps=125835 | ε=0.150 | reward=500.0
# Episode 729 | steps=125937 | ε=0.150 | reward=102.0
# Episode 730 | steps=126026 | ε=0.150 | reward=89.0
# Episode 731 | steps=126516 | ε=0.150 | reward=490.0
# Episode 732 | steps=126751 | ε=0.150 | reward=235.0
# Episode 733 | steps=127251 | ε=0.150 | reward=500.0
# Episode 734 | steps=127751 | ε=0.150 | reward=500.0
# Episode 735 | steps=128251 | ε=0.150 | reward=500.0
# Episode 736 | steps=128740 | ε=0.150 | reward=489.0
# Episode 737 | steps=129240 | ε=0.150 | reward=500.0
# Episode 738 | steps=129511 | ε=0.150 | reward=271.0
# Episode 739 | steps=130011 | ε=0.150 | reward=500.0
# Episode 740 | steps=130511 | ε=0.150 | reward=500.0
# Episode 741 | steps=131011 | ε=0.150 | reward=500.0
# Episode 742 | steps=131511 | ε=0.150 | reward=500.0
# Episode 743 | steps=132011 | ε=0.150 | reward=500.0
# Episode 744 | steps=132511 | ε=0.150 | reward=500.0
# Episode 745 | steps=133011 | ε=0.150 | reward=500.0
# Episode 746 | steps=133511 | ε=0.150 | reward=500.0
# Episode 747 | steps=134011 | ε=0.150 | reward=500.0
# Episode 748 | steps=134511 | ε=0.150 | reward=500.0
# Episode 749 | steps=135011 | ε=0.150 | reward=500.0
# Episode 750 | steps=135511 | ε=0.150 | reward=500.0
# Episode 751 | steps=136011 | ε=0.150 | reward=500.0
# Episode 752 | steps=136511 | ε=0.150 | reward=500.0
# Episode 753 | steps=137011 | ε=0.150 | reward=500.0
# Episode 754 | steps=137511 | ε=0.150 | reward=500.0
# Episode 755 | steps=138011 | ε=0.150 | reward=500.0
# Episode 756 | steps=138511 | ε=0.150 | reward=500.0
# Episode 757 | steps=139011 | ε=0.150 | reward=500.0
# Episode 758 | steps=139511 | ε=0.150 | reward=500.0
# Episode 759 | steps=140011 | ε=0.150 | reward=500.0
# Episode 760 | steps=140410 | ε=0.150 | reward=399.0
# Episode 761 | steps=140910 | ε=0.150 | reward=500.0
# Episode 762 | steps=141410 | ε=0.150 | reward=500.0
# Episode 763 | steps=141910 | ε=0.150 | reward=500.0
# Episode 764 | steps=142410 | ε=0.150 | reward=500.0
# Episode 765 | steps=142910 | ε=0.150 | reward=500.0
# Episode 766 | steps=143410 | ε=0.150 | reward=500.0
# Episode 767 | steps=143910 | ε=0.150 | reward=500.0
# Episode 768 | steps=144410 | ε=0.150 | reward=500.0
# Episode 769 | steps=144874 | ε=0.150 | reward=464.0
# Episode 770 | steps=145374 | ε=0.150 | reward=500.0
# Episode 771 | steps=145874 | ε=0.150 | reward=500.0
# Episode 772 | steps=146374 | ε=0.150 | reward=500.0
# Episode 773 | steps=146874 | ε=0.150 | reward=500.0
# Episode 774 | steps=147374 | ε=0.150 | reward=500.0
# Episode 775 | steps=147874 | ε=0.150 | reward=500.0
# Episode 776 | steps=147890 | ε=0.150 | reward=16.0
# Episode 777 | steps=148390 | ε=0.150 | reward=500.0
# Episode 778 | steps=148890 | ε=0.150 | reward=500.0
# Episode 779 | steps=149390 | ε=0.150 | reward=500.0
# Episode 780 | steps=149890 | ε=0.150 | reward=500.0
# Episode 781 | steps=150390 | ε=0.150 | reward=500.0
# Episode 782 | steps=150890 | ε=0.150 | reward=500.0
# Episode 783 | steps=151390 | ε=0.150 | reward=500.0
# Episode 784 | steps=151890 | ε=0.150 | reward=500.0
# Episode 785 | steps=152390 | ε=0.150 | reward=500.0
# Episode 786 | steps=152890 | ε=0.150 | reward=500.0
# Episode 787 | steps=153390 | ε=0.150 | reward=500.0
# Episode 788 | steps=153890 | ε=0.150 | reward=500.0
# Episode 789 | steps=154390 | ε=0.150 | reward=500.0
# Episode 790 | steps=154551 | ε=0.150 | reward=161.0
# Episode 791 | steps=154761 | ε=0.150 | reward=210.0
# Episode 792 | steps=154820 | ε=0.150 | reward=59.0
# Episode 793 | steps=154982 | ε=0.150 | reward=162.0
# Episode 794 | steps=155132 | ε=0.150 | reward=150.0
# Episode 795 | steps=155285 | ε=0.150 | reward=153.0
# Episode 796 | steps=155398 | ε=0.150 | reward=113.0
# Episode 797 | steps=155506 | ε=0.150 | reward=108.0
# Episode 798 | steps=155584 | ε=0.150 | reward=78.0
# Episode 799 | steps=155602 | ε=0.150 | reward=18.0
# Episode 800 | steps=155671 | ε=0.150 | reward=69.0
# Episode 801 | steps=155759 | ε=0.150 | reward=88.0
# Episode 802 | steps=155772 | ε=0.150 | reward=13.0
# Episode 803 | steps=155818 | ε=0.150 | reward=46.0
# Episode 804 | steps=155872 | ε=0.150 | reward=54.0
# Episode 805 | steps=155888 | ε=0.150 | reward=16.0
# Episode 806 | steps=155980 | ε=0.150 | reward=92.0
# Episode 807 | steps=156069 | ε=0.150 | reward=89.0
# Episode 808 | steps=156149 | ε=0.150 | reward=80.0
# Episode 809 | steps=156231 | ε=0.150 | reward=82.0
# Episode 810 | steps=156249 | ε=0.150 | reward=18.0
# Episode 811 | steps=156331 | ε=0.150 | reward=82.0
# Episode 812 | steps=156507 | ε=0.150 | reward=176.0
# Episode 813 | steps=156524 | ε=0.150 | reward=17.0
# Episode 814 | steps=156536 | ε=0.150 | reward=12.0
# Episode 815 | steps=156551 | ε=0.150 | reward=15.0
# Episode 816 | steps=156664 | ε=0.150 | reward=113.0
# Episode 817 | steps=156785 | ε=0.150 | reward=121.0
# Episode 818 | steps=156931 | ε=0.150 | reward=146.0
# Episode 819 | steps=157023 | ε=0.150 | reward=92.0
# Episode 820 | steps=157039 | ε=0.150 | reward=16.0
# Episode 821 | steps=157131 | ε=0.150 | reward=92.0
# Episode 822 | steps=157282 | ε=0.150 | reward=151.0
# Episode 823 | steps=157400 | ε=0.150 | reward=118.0
# Episode 824 | steps=157541 | ε=0.150 | reward=141.0
# Episode 825 | steps=157726 | ε=0.150 | reward=185.0
# Episode 826 | steps=157872 | ε=0.150 | reward=146.0
# Episode 827 | steps=158003 | ε=0.150 | reward=131.0
# Episode 828 | steps=158014 | ε=0.150 | reward=11.0
# Episode 829 | steps=158032 | ε=0.150 | reward=18.0
# Episode 830 | steps=158164 | ε=0.150 | reward=132.0
# Episode 831 | steps=158182 | ε=0.150 | reward=18.0
# Episode 832 | steps=158296 | ε=0.150 | reward=114.0
# Episode 833 | steps=158413 | ε=0.150 | reward=117.0
# Episode 834 | steps=158426 | ε=0.150 | reward=13.0
# Episode 835 | steps=158444 | ε=0.150 | reward=18.0
# Episode 836 | steps=158553 | ε=0.150 | reward=109.0
# Episode 837 | steps=158590 | ε=0.150 | reward=37.0
# Episode 838 | steps=158696 | ε=0.150 | reward=106.0
# Episode 839 | steps=158715 | ε=0.150 | reward=19.0
# Episode 840 | steps=158827 | ε=0.150 | reward=112.0
# Episode 841 | steps=158927 | ε=0.150 | reward=100.0
# Episode 842 | steps=158939 | ε=0.150 | reward=12.0
# Episode 843 | steps=159046 | ε=0.150 | reward=107.0
# Episode 844 | steps=159063 | ε=0.150 | reward=17.0
# Episode 845 | steps=159166 | ε=0.150 | reward=103.0
# Episode 846 | steps=159273 | ε=0.150 | reward=107.0
# Episode 847 | steps=159381 | ε=0.150 | reward=108.0
# Episode 848 | steps=159482 | ε=0.150 | reward=101.0
# Episode 849 | steps=159496 | ε=0.150 | reward=14.0
# Episode 850 | steps=159517 | ε=0.150 | reward=21.0
# Episode 851 | steps=159528 | ε=0.150 | reward=11.0
# Episode 852 | steps=159544 | ε=0.150 | reward=16.0
# Episode 853 | steps=159642 | ε=0.150 | reward=98.0
# Episode 854 | steps=159661 | ε=0.150 | reward=19.0
# Episode 855 | steps=159772 | ε=0.150 | reward=111.0
# Episode 856 | steps=159876 | ε=0.150 | reward=104.0
# Episode 857 | steps=159985 | ε=0.150 | reward=109.0
# Episode 858 | steps=160004 | ε=0.150 | reward=19.0
# Episode 859 | steps=160016 | ε=0.150 | reward=12.0
# Episode 860 | steps=160038 | ε=0.150 | reward=22.0
# Episode 861 | steps=160053 | ε=0.150 | reward=15.0
# Episode 862 | steps=160157 | ε=0.150 | reward=104.0
# Episode 863 | steps=160177 | ε=0.150 | reward=20.0
# Episode 864 | steps=160286 | ε=0.150 | reward=109.0
# Episode 865 | steps=160389 | ε=0.150 | reward=103.0
# Episode 866 | steps=160405 | ε=0.150 | reward=16.0
# Episode 867 | steps=160508 | ε=0.150 | reward=103.0
# Episode 868 | steps=160620 | ε=0.150 | reward=112.0
# Episode 869 | steps=160752 | ε=0.150 | reward=132.0
# Episode 870 | steps=160858 | ε=0.150 | reward=106.0
# Episode 871 | steps=160964 | ε=0.150 | reward=106.0
# Episode 872 | steps=161067 | ε=0.150 | reward=103.0
# Episode 873 | steps=161175 | ε=0.150 | reward=108.0
# Episode 874 | steps=161286 | ε=0.150 | reward=111.0
# Episode 875 | steps=161392 | ε=0.150 | reward=106.0
# Episode 876 | steps=161495 | ε=0.150 | reward=103.0
# Episode 877 | steps=161603 | ε=0.150 | reward=108.0
# Episode 878 | steps=161616 | ε=0.150 | reward=13.0
# Episode 879 | steps=161721 | ε=0.150 | reward=105.0
# Episode 880 | steps=161827 | ε=0.150 | reward=106.0
# Episode 881 | steps=161929 | ε=0.150 | reward=102.0
# Episode 882 | steps=162032 | ε=0.150 | reward=103.0
# Episode 883 | steps=162135 | ε=0.150 | reward=103.0
# Episode 884 | steps=162244 | ε=0.150 | reward=109.0
# Episode 885 | steps=162354 | ε=0.150 | reward=110.0
# Episode 886 | steps=162462 | ε=0.150 | reward=108.0
# Episode 887 | steps=162570 | ε=0.150 | reward=108.0
# Episode 888 | steps=162682 | ε=0.150 | reward=112.0
# Episode 889 | steps=162787 | ε=0.150 | reward=105.0
# Episode 890 | steps=162896 | ε=0.150 | reward=109.0
# Episode 891 | steps=163016 | ε=0.150 | reward=120.0
# Episode 892 | steps=163124 | ε=0.150 | reward=108.0
# Episode 893 | steps=163231 | ε=0.150 | reward=107.0
# Episode 894 | steps=163339 | ε=0.150 | reward=108.0
# Episode 895 | steps=163450 | ε=0.150 | reward=111.0
# Episode 896 | steps=163564 | ε=0.150 | reward=114.0
# Episode 897 | steps=163678 | ε=0.150 | reward=114.0
# Episode 898 | steps=163692 | ε=0.150 | reward=14.0
# Episode 899 | steps=163808 | ε=0.150 | reward=116.0
# Episode 900 | steps=163920 | ε=0.150 | reward=112.0
# Episode 901 | steps=164036 | ε=0.150 | reward=116.0
# Episode 902 | steps=164148 | ε=0.150 | reward=112.0
# Episode 903 | steps=164256 | ε=0.150 | reward=108.0
# Episode 904 | steps=164374 | ε=0.150 | reward=118.0
# Episode 905 | steps=164483 | ε=0.150 | reward=109.0
# Episode 906 | steps=164595 | ε=0.150 | reward=112.0
# Episode 907 | steps=164709 | ε=0.150 | reward=114.0
# Episode 908 | steps=164822 | ε=0.150 | reward=113.0
# Episode 909 | steps=164929 | ε=0.150 | reward=107.0
# Episode 910 | steps=165039 | ε=0.150 | reward=110.0
# Episode 911 | steps=165151 | ε=0.150 | reward=112.0
# Episode 912 | steps=165261 | ε=0.150 | reward=110.0
# Episode 913 | steps=165371 | ε=0.150 | reward=110.0
# Episode 914 | steps=165489 | ε=0.150 | reward=118.0
# Episode 915 | steps=165607 | ε=0.150 | reward=118.0
# Episode 916 | steps=165721 | ε=0.150 | reward=114.0
# Episode 917 | steps=165834 | ε=0.150 | reward=113.0
# Episode 918 | steps=165947 | ε=0.150 | reward=113.0
# Episode 919 | steps=166068 | ε=0.150 | reward=121.0
# Episode 920 | steps=166186 | ε=0.150 | reward=118.0
# Episode 921 | steps=166304 | ε=0.150 | reward=118.0
# Episode 922 | steps=166420 | ε=0.150 | reward=116.0
# Episode 923 | steps=166535 | ε=0.150 | reward=115.0
# Episode 924 | steps=166656 | ε=0.150 | reward=121.0
# Episode 925 | steps=166771 | ε=0.150 | reward=115.0
# Episode 926 | steps=166889 | ε=0.150 | reward=118.0
# Episode 927 | steps=167011 | ε=0.150 | reward=122.0
# Episode 928 | steps=167135 | ε=0.150 | reward=124.0
# Episode 929 | steps=167252 | ε=0.150 | reward=117.0
# Episode 930 | steps=167374 | ε=0.150 | reward=122.0
# Episode 931 | steps=167489 | ε=0.150 | reward=115.0
# Episode 932 | steps=167601 | ε=0.150 | reward=112.0
# Episode 933 | steps=167722 | ε=0.150 | reward=121.0
# Episode 934 | steps=167841 | ε=0.150 | reward=119.0
# Episode 935 | steps=167964 | ε=0.150 | reward=123.0
# Episode 936 | steps=168090 | ε=0.150 | reward=126.0
# Episode 937 | steps=168216 | ε=0.150 | reward=126.0
# Episode 938 | steps=168329 | ε=0.150 | reward=113.0
# Episode 939 | steps=168446 | ε=0.150 | reward=117.0
# Episode 940 | steps=168576 | ε=0.150 | reward=130.0
# Episode 941 | steps=168698 | ε=0.150 | reward=122.0
# Episode 942 | steps=168820 | ε=0.150 | reward=122.0
# Episode 943 | steps=168952 | ε=0.150 | reward=132.0
# Episode 944 | steps=169090 | ε=0.150 | reward=138.0
# Episode 945 | steps=169222 | ε=0.150 | reward=132.0
# Episode 946 | steps=169347 | ε=0.150 | reward=125.0
# Episode 947 | steps=169488 | ε=0.150 | reward=141.0
# Episode 948 | steps=169623 | ε=0.150 | reward=135.0
# Episode 949 | steps=169742 | ε=0.150 | reward=119.0
# Episode 950 | steps=169869 | ε=0.150 | reward=127.0
# Episode 951 | steps=169990 | ε=0.150 | reward=121.0
# Episode 952 | steps=170120 | ε=0.150 | reward=130.0
# Episode 953 | steps=170253 | ε=0.150 | reward=133.0
# Episode 954 | steps=170390 | ε=0.150 | reward=137.0
# Episode 955 | steps=170515 | ε=0.150 | reward=125.0
# Episode 956 | steps=170655 | ε=0.150 | reward=140.0
# Episode 957 | steps=170797 | ε=0.150 | reward=142.0
# Episode 958 | steps=170933 | ε=0.150 | reward=136.0
# Episode 959 | steps=171060 | ε=0.150 | reward=127.0
# Episode 960 | steps=171203 | ε=0.150 | reward=143.0
# Episode 961 | steps=171340 | ε=0.150 | reward=137.0
# Episode 962 | steps=171490 | ε=0.150 | reward=150.0
# Episode 963 | steps=171638 | ε=0.150 | reward=148.0
# Episode 964 | steps=171776 | ε=0.150 | reward=138.0
# Episode 965 | steps=171922 | ε=0.150 | reward=146.0
# Episode 966 | steps=172075 | ε=0.150 | reward=153.0
# Episode 967 | steps=172218 | ε=0.150 | reward=143.0
# Episode 968 | steps=172379 | ε=0.150 | reward=161.0
# Episode 969 | steps=172532 | ε=0.150 | reward=153.0
# Episode 970 | steps=172670 | ε=0.150 | reward=138.0
# Episode 971 | steps=172817 | ε=0.150 | reward=147.0
# Episode 972 | steps=172984 | ε=0.150 | reward=167.0
# Episode 973 | steps=173143 | ε=0.150 | reward=159.0
# Episode 974 | steps=173292 | ε=0.150 | reward=149.0
# Episode 975 | steps=173449 | ε=0.150 | reward=157.0
# Episode 976 | steps=173645 | ε=0.150 | reward=196.0
# Episode 977 | steps=173885 | ε=0.150 | reward=240.0
# Episode 978 | steps=174092 | ε=0.150 | reward=207.0
# Episode 979 | steps=174592 | ε=0.150 | reward=500.0
# Episode 980 | steps=175092 | ε=0.150 | reward=500.0
# Episode 981 | steps=175592 | ε=0.150 | reward=500.0
# Episode 982 | steps=176092 | ε=0.150 | reward=500.0
# Episode 983 | steps=176592 | ε=0.150 | reward=500.0
# Episode 984 | steps=177092 | ε=0.150 | reward=500.0
# Episode 985 | steps=177592 | ε=0.150 | reward=500.0
# Episode 986 | steps=178092 | ε=0.150 | reward=500.0
# Episode 987 | steps=178592 | ε=0.150 | reward=500.0
# Episode 988 | steps=179092 | ε=0.150 | reward=500.0
# Episode 989 | steps=179592 | ε=0.150 | reward=500.0
# Episode 990 | steps=180092 | ε=0.150 | reward=500.0
# Episode 991 | steps=180592 | ε=0.150 | reward=500.0
# Episode 992 | steps=181092 | ε=0.150 | reward=500.0
# Episode 993 | steps=181592 | ε=0.150 | reward=500.0
# Episode 994 | steps=182092 | ε=0.150 | reward=500.0
# Episode 995 | steps=182592 | ε=0.150 | reward=500.0
# Episode 996 | steps=183092 | ε=0.150 | reward=500.0
# Episode 997 | steps=183592 | ε=0.150 | reward=500.0
# Episode 998 | steps=184092 | ε=0.150 | reward=500.0
# Episode 999 | steps=184592 | ε=0.150 | reward=500.0

# %%
def evaluate_policy(eval_env, q_net, n_eval_episodes=10, max_steps=1000):
    q_net.eval()
    rewards = []

    for i in range(n_eval_episodes):
        with torch.no_grad():
            state, _ = env.reset()
            ep_reward = 0.0

            for _ in range(max_steps):
                state_t = torch.as_tensor(state, dtype=torch.float32).unsqueeze(0)
                q_values = q_net(state_t).squeeze(0)
                # Selección de la acción greedy - sin exploración
                action = torch.argmax(q_values).item()

                next_state, reward, terminated, truncated, _ = env.step(action)
                ep_reward += float(reward)
                if terminated or truncated:
                    break
                state = next_state
        rewards.append(ep_reward)

    mean_rewards = float(np.mean(rewards))
    std_rewards = float(np.std(rewards, ddof=1)) if len(rewards) >= 2 else 0.0
    return mean_rewards, std_rewards

# %%
eval_env = gym.make("CartPole-v1", render_mode="rgb_array")
mean_r, std_r = evaluate_policy(eval_env, online_network, n_eval_episodes=100)
print(f"Mean reward: {mean_r:.2f} | Std reward: {std_r:.2f}")
# Out:
# Mean reward: 500.00 | Std reward: 0.00

# %%
frames = []
state, _ = eval_env.reset()
totalReward = 0
for i in range(1000):
    state_t = torch.as_tensor(state, dtype=torch.float32).unsqueeze(0)
    q_values = online_network(state_t).squeeze(0)
    action = torch.argmax(q_values).item()

    next_state, reward, terminated, truncated, _ = eval_env.step(action)
    frame = eval_env.render()
    frames.append(frame)
    totalReward += reward
    if terminated or truncated:
        print("Ended")
        print(i)
        print(terminated)
        print(truncated)
        break
    state = next_state

# Guardar como GIF
imageio.mimsave("cartpole.gif", frames, duration=150)
print("Reward", totalReward)
# Out:
# Ended
# 8
# True
# False
# Reward 9.0

# %%
files.download("cartpole.gif")

# %%
env.close()

# %%
eval_env.close()

# %%
env = gym.make('CartPole-v1')

# %%
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

# %%
class PolicyNetwork(nn.Module):
    def __init__(self, state_size, action_size):
        super(PolicyNetwork, self).__init__()
        self.fc1 = nn.Linear(state_size, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, action_size)

    def forward(self, state):
        # fc1 - relu - fc2 - relu - fc3 - softmax
        x = torch.relu(self.fc1(state))
        x = torch.relu(self.fc2(x))
        action_probs = torch.softmax(self.fc3(x), dim=-1)
        return action_probs

# %%
class BaseNetwork(nn.Module):
    def __init__(self, state_size):
        super(BaseNetwork, self).__init__()
        self.fc1 = nn.Linear(state_size, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, 1)

    def forward(self, state):
        # fc1 - relu - fc2 - relu - fc3 - softmax
        x = torch.relu(self.fc1(state))
        x = torch.relu(self.fc2(x))
        Gt = torch.relu(self.fc3(x))

        return Gt

# %%
def train_reinforce(policy, policy_optimizer, baseNet, baseNet_optimizer,n_episodes, gamma):
    # Almacenamos la recompensa total de cada episodio
    episode_returns = []
    # Iteramos sobre el número de episodios de entrenamiento
    for episode in range(n_episodes):
        # Reseteamos el entorno
        state, _ = env.reset()
        # Almacenamos las (log) probabilidades y las recompensas de cada timestep
        log_probs = []
        rewards = []
        base_rewards = []

        total_reward = 0
        steps = 0
        done = False

        # Red policy en modo entrenamiento
        policy.train()

        while not done:
            # Prepararemos la variable state para su entrada a la red neuronal
            state = torch.from_numpy(state).float().unsqueeze(0)
            # Obtenemos el output de la red policy
            action_probs = policy(state)

            # Escogeremos una acción a partir de esta distribución de probabilidades
            # y guardaremos su (log) probabilidad
            dist = torch.distributions.Categorical(action_probs)
            action = dist.sample()
            log_prob = dist.log_prob(action)

            # Ejecutamos un paso en el entorno con la acción escogida
            next_state, reward, terminated, truncated, _ = env.step(action.item())
            # Actualizamos el indicador de finalización de episodio
            done = terminated or truncated
            base_reward = baseNet(state)
            # Guardamos la información relevante
            log_probs.append(log_prob)
            rewards.append(reward)
            base_rewards.append(base_reward)
            # Actualizamos
            total_reward += reward
            steps += 1
            state = next_state

        # Obtenemos el retorno esperado del episodio recorriéndolo al revés (Monte Carlo)
        loss_base = 0
        returns_base = []
        G = 0
        i = len(rewards)-1
        for r in reversed(rewards):
            G = r + gamma * G
            returns_base.insert(0, G-base_rewards[i])
            loss_base += (G-base_rewards[i])**2
            i -= 1

        log_probs = torch.cat(log_probs)

        # Normalización del retorno para dar estabilidad
        returns_base = torch.tensor(returns_base)

        normalized_returns = (returns_base - returns_base.mean()) / returns_base.std()
        normalized_returns = normalized_returns.detach()

        # Calculamos la función de pérdida
        loss = -(normalized_returns * log_probs).sum()

        # Backpropagation policy
        policy_optimizer.zero_grad()
        loss.backward()
        policy_optimizer.step()

        # Backpropagation base
        baseNet_optimizer.zero_grad()
        loss_base.backward()
        baseNet_optimizer.step()
        episode_returns.append(total_reward)

        if episode % 10 == 0:
            print(f"| Episodio {episode} | Recompensa total: {total_reward} |")

# %%
n_episodes = 800
learning_rate = 0.001
gamma = 0.99

policy = PolicyNetwork(state_size, action_size)
baseNet = BaseNetwork(state_size)
optimizer = optim.Adam(policy.parameters(), lr=learning_rate)
base_optimizer = optim.Adam(baseNet.parameters(), lr=learning_rate)
train_reinforce(policy, optimizer, baseNet,base_optimizer,n_episodes, gamma)
# Out:
# /tmp/ipython-input-2064420589.py:60: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   returns_base = torch.tensor(returns_base)
# | Episodio 0 | Recompensa total: 10.0 |
# | Episodio 10 | Recompensa total: 42.0 |
# | Episodio 20 | Recompensa total: 11.0 |
# | Episodio 30 | Recompensa total: 17.0 |
# | Episodio 40 | Recompensa total: 29.0 |
# | Episodio 50 | Recompensa total: 20.0 |
# | Episodio 60 | Recompensa total: 14.0 |
# | Episodio 70 | Recompensa total: 38.0 |
# | Episodio 80 | Recompensa total: 29.0 |
# | Episodio 90 | Recompensa total: 52.0 |
# | Episodio 100 | Recompensa total: 40.0 |
# | Episodio 110 | Recompensa total: 88.0 |
# | Episodio 120 | Recompensa total: 49.0 |
# | Episodio 130 | Recompensa total: 23.0 |
# | Episodio 140 | Recompensa total: 56.0 |
# | Episodio 150 | Recompensa total: 35.0 |
# | Episodio 160 | Recompensa total: 346.0 |
# | Episodio 170 | Recompensa total: 139.0 |
# | Episodio 180 | Recompensa total: 40.0 |
# | Episodio 190 | Recompensa total: 102.0 |
# | Episodio 200 | Recompensa total: 293.0 |
# | Episodio 210 | Recompensa total: 303.0 |
# | Episodio 220 | Recompensa total: 389.0 |
# | Episodio 230 | Recompensa total: 200.0 |
# | Episodio 240 | Recompensa total: 116.0 |
# | Episodio 250 | Recompensa total: 28.0 |
# | Episodio 260 | Recompensa total: 26.0 |
# | Episodio 270 | Recompensa total: 20.0 |
# | Episodio 280 | Recompensa total: 16.0 |
# | Episodio 290 | Recompensa total: 24.0 |
# | Episodio 300 | Recompensa total: 17.0 |
# | Episodio 310 | Recompensa total: 27.0 |
# | Episodio 320 | Recompensa total: 26.0 |
# | Episodio 330 | Recompensa total: 56.0 |
# | Episodio 340 | Recompensa total: 57.0 |
# | Episodio 350 | Recompensa total: 44.0 |
# | Episodio 360 | Recompensa total: 113.0 |
# | Episodio 370 | Recompensa total: 139.0 |
# | Episodio 380 | Recompensa total: 230.0 |
# | Episodio 390 | Recompensa total: 500.0 |
# | Episodio 400 | Recompensa total: 431.0 |
# | Episodio 410 | Recompensa total: 500.0 |
# | Episodio 420 | Recompensa total: 444.0 |
# | Episodio 430 | Recompensa total: 107.0 |
# | Episodio 440 | Recompensa total: 500.0 |
# | Episodio 450 | Recompensa total: 500.0 |
# | Episodio 460 | Recompensa total: 307.0 |
# | Episodio 470 | Recompensa total: 500.0 |
# | Episodio 480 | Recompensa total: 500.0 |
# | Episodio 490 | Recompensa total: 168.0 |
# | Episodio 500 | Recompensa total: 351.0 |
# | Episodio 510 | Recompensa total: 500.0 |
# | Episodio 520 | Recompensa total: 500.0 |
# | Episodio 530 | Recompensa total: 500.0 |
# | Episodio 540 | Recompensa total: 500.0 |
# | Episodio 550 | Recompensa total: 500.0 |
# | Episodio 560 | Recompensa total: 10.0 |
# | Episodio 570 | Recompensa total: 21.0 |
# | Episodio 580 | Recompensa total: 104.0 |
# | Episodio 590 | Recompensa total: 130.0 |
# | Episodio 600 | Recompensa total: 155.0 |
# | Episodio 610 | Recompensa total: 322.0 |
# | Episodio 620 | Recompensa total: 500.0 |
# | Episodio 630 | Recompensa total: 500.0 |
# | Episodio 640 | Recompensa total: 500.0 |
# | Episodio 650 | Recompensa total: 500.0 |
# | Episodio 660 | Recompensa total: 500.0 |
# | Episodio 670 | Recompensa total: 500.0 |
# | Episodio 680 | Recompensa total: 500.0 |
# | Episodio 690 | Recompensa total: 500.0 |
# | Episodio 700 | Recompensa total: 500.0 |
# | Episodio 710 | Recompensa total: 500.0 |
# | Episodio 720 | Recompensa total: 500.0 |
# | Episodio 730 | Recompensa total: 500.0 |
# | Episodio 740 | Recompensa total: 500.0 |
# | Episodio 750 | Recompensa total: 500.0 |
# | Episodio 760 | Recompensa total: 500.0 |
# | Episodio 770 | Recompensa total: 500.0 |
# | Episodio 780 | Recompensa total: 500.0 |
# | Episodio 790 | Recompensa total: 500.0 |

# %%
env.close()

# %%
eval_env = gym.make('CartPole-v1', render_mode='rgb_array')

# %%
def evaluate_agent(policy, env, n_episodes=10):
    # Política en modo evaluación
    policy.eval()
    episode_rewards = []

    for episode in range(n_episodes):
        state, _ = env.reset()
        done = False
        episode_reward = 0

        while not done:
            state = torch.from_numpy(state).float().unsqueeze(0)
            with torch.no_grad():
                action_probs = policy(state)
                # Escogemos acción determinista
                action = torch.argmax(action_probs, dim=-1).item()

            next_state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            episode_reward += reward
            state = next_state

        episode_rewards.append(episode_reward)

    avg_reward = np.mean(episode_rewards)
    std_reward = np.std(episode_rewards)
    print(f"\n>>> Recompensa promedio en evaluación sobre {n_episodes} episodios: {avg_reward} +/- {std_reward}")

# %%
evaluate_agent(policy, eval_env)
# Out:
# >>> Recompensa promedio en evaluación sobre 10 episodios: 500.0 +/- 0.0

# %%
def run_episode(env, policy):
    frames = []
    policy.eval()
    state, _ = env.reset()
    done = False

    while not done:
        state = torch.from_numpy(state).float().unsqueeze(0)
        with torch.no_grad():
            action_probs = policy(state)
            action = torch.argmax(action_probs, dim=-1).item()  # Acción determinista

        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        state = next_state
        frames.append(env.render())

    return frames

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import imageio
from IPython.display import HTML
# Crear animación
frames = run_episode(eval_env, policy)
fig = plt.figure()
img = plt.imshow(frames[0])

def animate(i):
    img.set_data(frames[i])
    return [img]

ani = animation.FuncAnimation(fig, animate, frames=len(frames), interval=50, blit=True)
plt.close(fig)
HTML(ani.to_jshtml())
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
eval_env.close()
